# %%
# Import Libraries
import requests
import urllib.request
from bs4 import BeautifulSoup
import re
import datetime
import csv
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-109-d8b2342711a3> in <module>
#       6 import datetime
#       7 import csv
# ----> 8 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def get_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
class GreenhousePage:
    def __init__(self, slug):
        self.slug = slug
        self.run_date = datetime.date.today().strftime("%Y-%b-%d")  
        self.url = 'https://boards.greenhouse.io/' + self.slug
        self.load_soup()
        self.title = self.soup.find("meta", property = "og:title")['content']
        self.sections = []
        self.get_sections()
        self.jobs_data = [['category','job_title','page_link','job_id', 'location', 'run_date']]
        self.load_jobs()
        self.load_dataframe()
    
    def load_jobs(self):
        sec_divs = self.soup.findAll("section")
        for sec in sec_divs:
            
            all_links = sec.findAll('a', attrs={'data-mapped': 'true'})
            for link in all_links:
                category = link.find_previous("h3").text
                job_title = link.contents[0]
                page_link = 'https://boards.greenhouse.io' + link['href']
                job_id = link['href'][len(self.slug + "/jobs/") + 1:]
                location = link.find_next_sibling('span').text
                self.jobs_data.append([category, job_title, page_link, job_id, location, self.run_date])
    
    def load_dataframe(self):
        self.jobs = pd.DataFrame(self.jobs_data[1:], columns = self.jobs_data[0])
            
    def get_sections(self):
        if not self.soup:
            self.load_soup()
        sec_divs = self.soup.findAll("section")
        for sec in sec_divs:
            try:
                sec_title = sec.find("h3").text
                self.sections.append(sec_title)
            except:
                pass
            
    def load_soup(self):
        response = requests.get(self.url)
        self.soup = BeautifulSoup(response.text, 'html.parser')
        
    def print_html(self):
        print(self.soup.prettify())

# %%
# The base job page URL for Bernie 2020
#base_url = 'https://boards.greenhouse.io/bernie2020'
#base_url = 'https://boards.greenhouse.io/gitlab'

#gitlab_page = GreenhousePage('gitlab')
bernie_page = GreenhousePage('bernie2020')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-f89ea0befb35> in <module>
#       4
#       5 #gitlab_page = GreenhousePage('gitlab')
# ----> 6 bernie_page = GreenhousePage('bernie2020')
#
# <ipython-input-107-dd0e4e944307> in __init__(self, slug)
#      10         self.jobs_data = [['category','job_title','page_link','job_id', 'location', 'run_date']]
#      11         self.load_jobs()
# ---> 12         self.load_dataframe()
#      13
#      14     def load_jobs(self):
#
# <ipython-input-107-dd0e4e944307> in load_dataframe(self)
#      26
#      27     def load_dataframe(self):
# ---> 28         self.jobs = pd.DataFrame(self.jobs_data[1:], columns = self.jobs_data[0])
#      29
#      30     def get_sections(self):
#
# NameError: name 'pd' is not defined

# %%
bernie_page.jobs
# Out:
# [['category', 'job_title', 'page_link', 'job_id', 'location', 'run_date'],
#  ['All Departments',
#   'California Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274391002',
#   '4274391002',
#   'California ',
#   '2019-Nov-14'],
#  ['All Departments',
#   'Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274408002',
#   '4274408002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['All Departments',
#   'Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4263816002',
#   '4263816002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['All Departments',
#   'General Application',
#   'https://boards.greenhouse.io/bernie2020/jobs/4231325002',
#   '4231325002',
#   'Multiple Locations',
#   '2019-Nov-14'],
#  ['All Departments',
#   'HQ Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274405002',
#   '4274405002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['All Departments',
#   'Iowa Student Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4461162002',
#   '4461162002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['All Departments',
#   'Nevada Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274412002',
#   '4274412002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['All Departments',
#   'Nevada Youth Field Fellowship Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4334036002',
#   '4334036002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['All Departments',
#   'New Hampshire Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274418002',
#   '4274418002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['All Departments',
#   'New Hampshire Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4272302002',
#   '4272302002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['All Departments',
#   'South Carolina Campaign Intern ',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274430002',
#   '4274430002',
#   'South Carolina ',
#   '2019-Nov-14'],
#  ['All Departments',
#   'Vermont Campaign Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4274440002',
#   '4274440002',
#   'Vermont',
#   '2019-Nov-14'],
#  ['Communications',
#   'Communications Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4262445002',
#   '4262445002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['Communications',
#   'Graphic Design Associate',
#   'https://boards.greenhouse.io/bernie2020/jobs/4445765002',
#   '4445765002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['Communications',
#   'Northeast Regional Press Secretary',
#   'https://boards.greenhouse.io/bernie2020/jobs/4489875002',
#   '4489875002',
#   'Washington DC',
#   '2019-Nov-14'],
#  ['Data + Technology',
#   'Data Analyst',
#   'https://boards.greenhouse.io/bernie2020/jobs/4269064002',
#   '4269064002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['Data + Technology',
#   'Full Stack Engineer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4244285002',
#   '4244285002',
#   'Washington, DC or remote',
#   '2019-Nov-14'],
#  ['Data + Technology',
#   'Iowa Data Intern',
#   'https://boards.greenhouse.io/bernie2020/jobs/4374451002',
#   '4374451002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Data + Technology',
#   'National Data Desk',
#   'https://boards.greenhouse.io/bernie2020/jobs/4489865002',
#   '4489865002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['Organizing',
#   'California Central Coast and Central Valley Area Field Director',
#   'https://boards.greenhouse.io/bernie2020/jobs/4450510002',
#   '4450510002',
#   'California',
#   '2019-Nov-14'],
#  ['Organizing',
#   'California Field Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4273091002',
#   '4273091002',
#   'California',
#   '2019-Nov-14'],
#  ['Organizing',
#   'California Regional Field Director',
#   'https://boards.greenhouse.io/bernie2020/jobs/4273098002',
#   '4273098002',
#   'California',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Call Team National Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4489856002',
#   '4489856002',
#   'Remote',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Events Program Organizer ',
#   'https://boards.greenhouse.io/bernie2020/jobs/4284535002',
#   '4284535002',
#   'Remote',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Help Desk Program Organizer ',
#   'https://boards.greenhouse.io/bernie2020/jobs/4284268002',
#   '4284268002',
#   'Remote',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Campus Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4351475002',
#   '4351475002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Constituency Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4478483002',
#   '4478483002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Constituency Outreach Director',
#   'https://boards.greenhouse.io/bernie2020/jobs/4496297002',
#   '4496297002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Field Coordinator',
#   'https://boards.greenhouse.io/bernie2020/jobs/4374443002',
#   '4374443002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Field Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4265660002',
#   '4265660002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Regional Field Director-Region 9',
#   'https://boards.greenhouse.io/bernie2020/jobs/4412783002',
#   '4412783002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa Relational Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4496282002',
#   '4496282002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Iowa VAN Administrator',
#   'https://boards.greenhouse.io/bernie2020/jobs/4498175002',
#   '4498175002',
#   'Iowa',
#   '2019-Nov-14'],
#  ['Organizing',
#   'National Field Desk ',
#   'https://boards.greenhouse.io/bernie2020/jobs/4284529002',
#   '4284529002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['Organizing',
#   'National Out of State Volunteer Coordinator',
#   'https://boards.greenhouse.io/bernie2020/jobs/4416463002',
#   '4416463002',
#   'Remote',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Nevada Campus Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4505040002',
#   '4505040002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Nevada Constituency Field Director',
#   'https://boards.greenhouse.io/bernie2020/jobs/4505051002',
#   '4505051002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Nevada Constituency Field Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4505044002',
#   '4505044002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Nevada Deputy Field Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4505027002',
#   '4505027002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Nevada Field Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4265691002',
#   '4265691002',
#   'Nevada',
#   '2019-Nov-14'],
#  ['Organizing',
#   'New Hampshire Campus Outreach Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4380795002',
#   '4380795002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['Organizing',
#   'New Hampshire Field Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4265717002',
#   '4265717002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['Organizing',
#   'New Hampshire Regional Field Director Region 1',
#   'https://boards.greenhouse.io/bernie2020/jobs/4489843002',
#   '4489843002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['Organizing',
#   'New Hampshire Regional Field Director Region 6',
#   'https://boards.greenhouse.io/bernie2020/jobs/4496315002',
#   '4496315002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['Organizing',
#   'New Hampshire Regional Field Director Region 7',
#   'https://boards.greenhouse.io/bernie2020/jobs/4498198002',
#   '4498198002',
#   'New Hampshire',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Sacramento Northern California Area Director',
#   'https://boards.greenhouse.io/bernie2020/jobs/4496329002',
#   '4496329002',
#   'California',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Sacramento Northern California Area Field Director',
#   'https://boards.greenhouse.io/bernie2020/jobs/4496337002',
#   '4496337002',
#   'California',
#   '2019-Nov-14'],
#  ['Organizing',
#   'Text Team National Organizer',
#   'https://boards.greenhouse.io/bernie2020/jobs/4259989002',
#   '4259989002',
#   'Remote',
#   '2019-Nov-14'],
#  ['Policy + Research',
#   'Research Associate',
#   'https://boards.greenhouse.io/bernie2020/jobs/4446263002',
#   '4446263002',
#   'Washington, DC',
#   '2019-Nov-14'],
#  ['Political',
#   'National Political Project Manager',
#   'https://boards.greenhouse.io/bernie2020/jobs/4425215002',
#   '4425215002',
#   'Washington, DC ',
#   '2019-Nov-14'],
#  ['Political',
#   'Nevada Latinx Constituency Coordinator',
#   'https://boards.greenhouse.io/bernie2020/jobs/4505046002',
#   '4505046002',
#   'Las Vegas, Nevada',
#   '2019-Nov-14']]

# %%
# Get all job links
# <div class = "opening"> ... <a href...""
open_jobs = []
all_links = soup.findAll('a', attrs={'data-mapped': 'true'})
for link in all_links:
    category = '' #@TODO Find previous h3 tag
    job_title = link.contents[0]
    page_link = 'https://boards.greenhouse.io' + link['href']
    open_jobs.append({'job_title': job_title, 'link': page_link})
print(f"There are currently {len(open_jobs)} open jobs")
# Out:
# There are currently 196 open jobs

# %%
# Process open jobs and save text
keyword = 'sql'
final_results = {}
for job in open_jobs:
    job_title = job['job_title']
    link = job['link']
   
    search_response = requests.get(link)
    search_soup = BeautifulSoup(search_response.text, 'html.parser')
    results = search_soup.body.find_all(string = re.compile('.*{0}.*'.format(keyword), re.IGNORECASE), recursive = True)
    
    if len(results) > 0:
        final_results[link] = {'job_title': job_title, 'result_count': len(results)}
        print(f'Found the word "{keyword}" {len(results)} times in {job_title} ({link})')
                
print(final_results)
# Out:
# Found the word "sql" 3 times in Operations Analyst, Development (https://boards.greenhouse.io/gitlab/jobs/4371373002)
# Found the word "sql" 3 times in Backend Engineer, Database (https://boards.greenhouse.io/gitlab/jobs/4473989002)
# Found the word "sql" 2 times in Backend Engineer, Search (https://boards.greenhouse.io/gitlab/jobs/4392358002)
# Found the word "sql" 2 times in Senior Security Engineer, Abuse (https://boards.greenhouse.io/gitlab/jobs/4489255002)
# Found the word "sql" 2 times in Finance Business Partner, Sales (https://boards.greenhouse.io/gitlab/jobs/4500567002)
# Found the word "sql" 2 times in Business Systems Analyst (https://boards.greenhouse.io/gitlab/jobs/4450334002)
# Found the word "sql" 5 times in Data Analyst (https://boards.greenhouse.io/gitlab/jobs/4441205002)
# Found the word "sql" 5 times in Data Analyst (https://boards.greenhouse.io/gitlab/jobs/4433341002)
# Found the word "sql" 5 times in Data Analyst (https://boards.greenhouse.io/gitlab/jobs/4416681002)
# Found the word "sql" 5 times in Data Engineer (Product/Engineering) (https://boards.greenhouse.io/gitlab/jobs/4513755002)
# Found the word "sql" 4 times in Data Engineer (S&M) (https://boards.greenhouse.io/gitlab/jobs/4456846002)
# Found the word "sql" 2 times in Director of Data and Analytics (https://boards.greenhouse.io/gitlab/jobs/4325127002)
# {'https://boards.greenhouse.io/gitlab/jobs/4371373002': {'job_title': 'Operations Analyst, Development', 'result_count': 3}, 'https://boards.greenhouse.io/gitlab/jobs/4473989002': {'job_title': 'Backend Engineer, Database', 'result_count': 3}, 'https://boards.greenhouse.io/gitlab/jobs/4392358002': {'job_title': 'Backend Engineer, Search', 'result_count': 2}, 'https://boards.greenhouse.io/gitlab/jobs/4489255002': {'job_title': 'Senior Security Engineer, Abuse', 'result_count': 2}, 'https://boards.greenhouse.io/gitlab/jobs/4500567002': {'job_title': 'Finance Business Partner, Sales', 'result_count': 2}, 'https://boards.greenhouse.io/gitlab/jobs/4450334002': {'job_title': 'Business Systems Analyst', 'result_count': 2}, 'https://boards.greenhouse.io/gitlab/jobs/4441205002': {'job_title': 'Data Analyst', 'result_count': 5}, 'https://boards.greenhouse.io/gitlab/jobs/4433341002': {'job_title': 'Data Analyst', 'result_count': 5}, 'https://boards.greenhouse.io/gitlab/jobs/4416681002': {'job_title': 'Data Analyst', 'result_count': 5}, 'https://boards.greenhouse.io/gitlab/jobs/4513755002': {'job_title': 'Data Engineer (Product/Engineering)', 'result_count': 5}, 'https://boards.greenhouse.io/gitlab/jobs/4456846002': {'job_title': 'Data Engineer (S&M)', 'result_count': 4}, 'https://boards.greenhouse.io/gitlab/jobs/4325127002': {'job_title': 'Director of Data and Analytics', 'result_count': 2}}
